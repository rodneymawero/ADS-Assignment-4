# %%
# 1. Import libraries
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2. Load the dataset
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
# Checking if there are null values in the dataset
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# 1. Demographic:
# a. Which 2 demographics have proven to be the most popular with the telco brand?
# b. If the marketing team wanted to increase customer retention, to whom should
# they target their advertisements to?

# %%
# Select demographic columns and churn
df = df[['customerID', 'gender', "SeniorCitizen", 'Partner', 'Dependents', "Churn"]]

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents Churn
# 0     7590-VHVEG  Female              0     Yes         No    No
# 1     5575-GNVDE    Male              0      No         No    No
# 2     3668-QPYBK    Male              0      No         No   Yes
# 3     7795-CFOCW    Male              0      No         No    No
# 4     9237-HQITU  Female              0      No         No   Yes
# ...          ...     ...            ...     ...        ...   ...
# 7038  6840-RESVB    Male              0     Yes        Yes    No
# 7039  2234-XADUH  Female              0     Yes        Yes    No
# 7040  4801-JZAZL  Female              0     Yes        Yes    No
# 7041  8361-LTMKD    Male              1     Yes         No   Yes
# 7042  3186-AJIEK    Male              0      No         No    No
#
# [7043 rows x 6 columns]

# %%
# define churn variables
churn_no = df[df['Churn'] == 'No']
churn_yes = df[df['Churn'] == 'Yes']

# %%
churn_no.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents Churn
# 0  7590-VHVEG  Female              0     Yes         No    No
# 1  5575-GNVDE    Male              0      No         No    No
# 3  7795-CFOCW    Male              0      No         No    No
# 6  1452-KIOVK    Male              0      No        Yes    No
# 7  6713-OKOMC  Female              0      No         No    No

# %%
churn_yes.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents Churn
# 2   3668-QPYBK    Male              0      No         No   Yes
# 4   9237-HQITU  Female              0      No         No   Yes
# 5   9305-CDSKC  Female              0      No         No   Yes
# 8   7892-POOKP  Female              0     Yes         No   Yes
# 13  0280-XJGEX    Male              0      No         No   Yes

# %%
# Categorical plot (catplot) 1 for visualizing the count of customers not churned by gender
demo_no = churn_no.groupby(['gender'])['customerID'].count().reset_index()

g = sns.catplot(data = demo_no, x = 'gender', y = 'customerID',  hue = 'gender', kind = 'bar')
# extract the matplotlib axes_subplot objects from the FacetGrid
ax = g.facet_axis(0, 0)  # or ax = g.axes.flat[0]

# iterate through the axes containers
for c in ax.containers:
    labels = [f'{(v.get_height() / 1000):.1f}K' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')

# %%
# Males customers are slightly more than females who still did business with the telco.

# %%
# Catplot for visualizing the count of customers not churned grouped by gender and whether they are Senior Citizens
demo_no = churn_no.groupby(['SeniorCitizen', 'gender'])['customerID'].count().reset_index()

g = sns.catplot(data = demo_no, x = 'SeniorCitizen', y = 'customerID',  hue = 'gender', kind = 'bar')
# extract the matplotlib axes_subplot objects from the FacetGrid
ax = g.facet_axis(0, 0)  # or ax = g.axes.flat[0]

# iterate through the axes containers
for c in ax.containers:
    labels = [f'{(v.get_height() / 1000):.1f}K' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')

# %%
# Most customers not churned are not Senior Citizens 4.5K (0). Senior Citizens are very few 0.6K

# %%
# Grouping by partners and gender
demo_no = churn_no.groupby(['Partner', 'gender'])['customerID'].count().reset_index()

g = sns.catplot(data = demo_no, x = 'Partner', y = 'customerID',  hue = 'gender', kind = 'bar')
# extract the matplotlib axes_subplot objects from the FacetGrid
ax = g.facet_axis(0, 0)  # or ax = g.axes.flat[0]

# iterate through the axes containers
for c in ax.containers:
    labels = [f'{(v.get_height() / 1000):.1f}K' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')

# %%
# The numbers of those who did not churn and had partners is higher (2.8K) than those without partners (2.5K).

# %%
# Grouping by dependents and gender
demo_no = churn_no.groupby(['Dependents', 'gender'])['customerID'].count().reset_index()

g = sns.catplot(data = demo_no, x = 'Dependents', y = 'customerID',  hue = 'gender', kind = 'bar')
# extract the matplotlib axes_subplot objects from the FacetGrid
ax = g.facet_axis(0, 0)  # or ax = g.axes.flat[0]

# iterate through the axes containers
for c in ax.containers:
    labels = [f'{(v.get_height() / 1000):.1f}K' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')

# %% [markdown]
# 1 a. Which 2 demographics have proven to be the most popular with the telco brand?
#     1. Those who are not Senior Citizens (4.5 K)
#     2. Those who do not have dependents  (3.4 K)

# %%
# Categorical plot (catplot) 2 for visualizing the count of customers churned
demo_yes = churn_yes.groupby(['gender'])['customerID'].count().reset_index()
g = sns.catplot(data = demo_yes, x = 'gender', y = 'customerID',  hue = 'gender', kind = 'bar')
# extract the matplotlib axes_subplot objects from the FacetGrid
ax = g.facet_axis(0, 0)  # or ax = g.axes.flat[0]

# iterate through the axes containers
for c in ax.containers:
    labels = [f'{(v.get_height() / 1000):.1f}K' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')

# %%
# The numbers of customers both male and female who stopped doing business with the Telco.

# %%
demo_yes = churn_yes.groupby(['gender', 'SeniorCitizen' ])['customerID'].count().reset_index()
g = sns.catplot(data = demo_yes, x = 'SeniorCitizen', y = 'customerID',  hue = 'gender', kind = 'bar')
# extract the matplotlib axes_subplot objects from the FacetGrid
ax = g.facet_axis(0, 0)  # or ax = g.axes.flat[0]

# iterate through the axes containers
for c in ax.containers:
    labels = [f'{(v.get_height() / 1000):.1f}K' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')

# %%
# Customer Churn was higher among those who are non senior citizen (1.4 K)

# %%
# Customer Churn grouping by gender and partner
demo_yes = churn_yes.groupby(['gender', 'Partner' ])['customerID'].count().reset_index()
g = sns.catplot(data = demo_yes, x = 'Partner', y = 'customerID',  hue = 'gender', kind = 'bar')
# extract the matplotlib axes_subplot objects from the FacetGrid
ax = g.facet_axis(0, 0)  # or ax = g.axes.flat[0]

# iterate through the axes containers
for c in ax.containers:
    labels = [f'{(v.get_height() / 1000):.1f}K' for v in c]
    ax.bar_label(c, labels=labels, label_type='edge')

# %%
# Customer churn higher among those with no partners (1.2K)

# %%
# Customer churn is higher among those without dependents (1.6 K)

# %% [markdown]
# 1.b. If the marketing team wanted to increase customer retention, to whom should they target their advertisements to?
#       Ans. The market team should target those without dependents, those who are non - Senior citizens and those without partners as customer churn is highest in these groups

# %% [markdown]
# Services

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")
df = df[['PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 
            'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'MonthlyCharges','Contract', 'Churn']]

# %%
df
# Out:
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# 1             Yes                No             DSL            Yes
# 2             Yes                No             DSL            Yes
# 3              No  No phone service             DSL            Yes
# 4             Yes                No     Fiber optic             No
# ...           ...               ...             ...            ...
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 0             Yes               No          No          No              No
# ...

# %%
services = df[['PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 
            'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies']]


for service in services:
    plt.figure(figsize = (12, 8))
    sns.barplot(x = service, y = 'MonthlyCharges', data = df, hue = 'Churn', )
    plt.title(service)
    plt.show()

# %% [markdown]
# 2. Services:
# a. Which 3 services are contributing to a higher monthly charge and resulting to
# customers churning? (Use visualizations in explaining your analysis)

# %%
# Among customers who churn monthly Charges are higher in most services. 

# The exception is Internet services (DSL and Fibreoptic services) that have lower monthly charges among customers who churn

# %% [markdown]
# 2 b. If the telco was to offer Phone as a standalone service, which type of contract
# would encourage customer retention?

# %%
phone_service = df[df['PhoneService'] == 'Yes']

# %%
phone_service
# Out:
#      PhoneService MultipleLines InternetService       OnlineSecurity  \
# 1             Yes            No             DSL                  Yes
# 2             Yes            No             DSL                  Yes
# 4             Yes            No     Fiber optic                   No
# 5             Yes           Yes     Fiber optic                   No
# 6             Yes           Yes     Fiber optic                   No
# ...           ...           ...             ...                  ...
# 7037          Yes            No              No  No internet service
# 7038          Yes           Yes             DSL                  Yes
# 7039          Yes           Yes     Fiber optic                   No
# 7041          Yes           Yes     Fiber optic                   No
# 7042          Yes            No     Fiber optic                  Yes
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 1                      No                  Yes                   No
# ...

# %%
plt.figure(figsize = (12, 8))
sns.countplot(data = phone_service, x = 'Contract', hue = 'Churn')
# Out:
# <AxesSubplot:xlabel='Contract', ylabel='count'>

# %% [markdown]
# 2 b. If the telco was to offer Phone as a standalone service, which type of contract
# would encourage customer retention?
#  The two year contract - it has the lowest customer churn. The month to month contract has more churn, despite being most popular.

# %% [markdown]
# Payment

# %% [markdown]
# 3. Payment: (Use visualizations in explaining your analysis)
# a. If the company was to streamline all its services into 3 bouquet packages, what
# monthly prices will be appropriate for the following packages to keep customers
# from churning:
# i. Basic
# ii. Plus
# iii. Premium
# b. Should the company strictly go paperless for their monthly billings as a technique
# of keeping their customers and why?

# %%
df
# Out:
#      PhoneService     MultipleLines InternetService OnlineSecurity  \
# 0              No  No phone service             DSL             No
# 1             Yes                No             DSL            Yes
# 2             Yes                No             DSL            Yes
# 3              No  No phone service             DSL            Yes
# 4             Yes                No     Fiber optic             No
# ...           ...               ...             ...            ...
# 7038          Yes               Yes             DSL            Yes
# 7039          Yes               Yes     Fiber optic             No
# 7040           No  No phone service             DSL            Yes
# 7041          Yes               Yes     Fiber optic             No
# 7042          Yes                No     Fiber optic            Yes
#
#      OnlineBackup DeviceProtection TechSupport StreamingTV StreamingMovies  \
# 0             Yes               No          No          No              No
# ...

# %%
#  Distribution plot of monthly charges.
plt.figure(figsize = (12, 8))
sns.displot(data = df, x = 'MonthlyCharges', col = 'Churn')

# %%
sns.boxplot(data=df, x='Churn', y='MonthlyCharges')
plt.xlabel('Churn')
plt.ylabel('Monthly Charges')
plt.title('Boxplot of Monthly Charges by Churn')
plt.show()

# %%
# 3 a. If the company was to streamline all its services into 3 bouquet packages, what
# monthly prices will be appropriate for the following packages to keep customers
# from churning:
# i. Basic      
# Basic--  $20
# Plus---- $55
# Premium- $80

# %% [markdown]
# Alternatively, we could use the quatile distribution of the values to identify the package prices for the three boquets as below:
#
#         i.	Basic - $25
#
#         ii.	Plus - $64
#
#         iii. Premium - $88

# %%
df = pd.read_csv("WA_Fn-UseC_-Telco-Customer-Churn.csv")
Monthly_Charges_Summary = df['MonthlyCharges'].describe()

# %%
Monthly_Charges_Summary
# Out:
# count    7043.000000
# mean       64.761692
# std        30.090047
# min        18.250000
# 25%        35.500000
# 50%        70.350000
# 75%        89.850000
# max       118.750000
# Name: MonthlyCharges, dtype: float64

# %% [markdown]
# b. Should the company strictly go paperless for their monthly billings as a technique
# of keeping their customers and why?

# %%
df['PaperlessBilling'].value_counts()
# Out:
# Yes    4171
# No     2872
# Name: PaperlessBilling, dtype: int64

# %%
plt.figure(figsize = (12, 8))
sns.countplot(data = df, x = 'PaperlessBilling', hue = 'Churn')
# Out:
# <AxesSubplot:xlabel='PaperlessBilling', ylabel='count'>

# %% [markdown]
# b. Should the company strictly go paperless for their monthly billings as a technique
# of keeping their customers and why?
#   # No. The company should not completely go paperless because its loyal customers prefer Paperless billing. Also, more customers who churn  use paperless billing.  The decision to strictly go paperless for monthly billings should be based on a comprehensive analysis of customer preferences, cost-effectiveness, environmental impact, convenience, and customer retention rates. The pros and cons should be considered before making a decision.
